# %% [markdown]
# # Loading dataset of coursework with scatter plot

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
loaddata=pd.read_csv('loaddataset.csv',error_bad_lines=False) # error handling for badlines
loaddata
# Out:
# b'Skipping line 2236: expected 2 fields, saw 3\n'
#       1.310000  10.010000
# 0         1.32      10.02
# 1         1.33      10.03
# 2         1.34      10.04
# 3         1.35      10.05
# 4         1.36      10.06
# 5         1.37      10.07
# 6         1.38      10.08
# 7         1.39      10.09
# 8         1.40      10.10
# 9         1.41      10.11
# 10        1.42      10.12
# 11        1.43      10.13
# 12        1.44      10.14
# 13        1.45      10.15
# 14        1.46      10.16
# 15        1.47      10.17
# 16        1.48      10.18
# 17        1.49      10.19
# 18        1.50      10.20
# 19        1.51      10.21
# 20        1.52      10.22
# 21        1.53      10.23
# 22        1.54      10.24
# 23        1.55      10.25
# 24        1.56      10.26
# 25        1.57      10.27
# 26        1.58      10.28
# 27        1.59      10.29
# 28        1.60      10.30
# 29        1.61      10.31
# ...        ...        ...
# 2204      1.31      32.06
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(loaddata['1.310000'], loaddata['10.010000'])# x represent loaddata[column1] and  y as loaddata[column2]
plt.show()
